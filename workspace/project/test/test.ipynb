# %%
# !pwd
# !ls
# Out:
# /home/workspace/project
# models	scripts  simulation.ipynb  test

# %%
# %load_ext autoreload
# %autoreload 2

from scripts import loaders
from scripts import utils as utl
from scripts import notebook_utils

# %%
MACRO_NAME = "test/colonnade"

results = utl.single_test(
        utl.quick_run(
            macro=MACRO_NAME,
            variables=dict(
                INPUT_BITS=1,
                WEIGHT_BITS=8,
                OUTPUT_BITS=16,
                FORCE_100MHZ=True,
            ),
        )
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/accelergy/utils/yaml.py:359, in load_yaml(path, data, include_dirs)
#     358 try:
# --> 359     parsed, data, include_dirs = load_file_and_includes(
#     360         path, data, include_dirs
#     361     )
#     362 except Exception as e:
#
# File /usr/local/lib/python3.10/dist-packages/accelergy/utils/yaml.py:296, in load_file_and_includes(path, data, include_dirs)
#     295 template = env.get_template(path_file)
# --> 296 string = template.render(data, undefined=StrictUndefined)
#     297 return string, data, include_dirs
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:1295, in Template.render(self, *args, **kwargs)
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# ...
